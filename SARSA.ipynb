# %%
# !pip install gymnasium
# Out:
# Requirement already satisfied: gymnasium in /opt/anaconda3/lib/python3.13/site-packages (1.3.0)
# Requirement already satisfied: numpy>=1.21.0 in /opt/anaconda3/lib/python3.13/site-packages (from gymnasium) (2.3.5)
# Requirement already satisfied: cloudpickle>=1.2.0 in /opt/anaconda3/lib/python3.13/site-packages (from gymnasium) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /opt/anaconda3/lib/python3.13/site-packages (from gymnasium) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /opt/anaconda3/lib/python3.13/site-packages (from gymnasium) (0.0.6)

# %%
# !pip install "gymnasium[toy-text]"
# Out:
# Requirement already satisfied: gymnasium[toy-text] in /opt/anaconda3/lib/python3.13/site-packages (1.3.0)
# Requirement already satisfied: numpy>=1.21.0 in /opt/anaconda3/lib/python3.13/site-packages (from gymnasium[toy-text]) (2.3.5)
# Requirement already satisfied: cloudpickle>=1.2.0 in /opt/anaconda3/lib/python3.13/site-packages (from gymnasium[toy-text]) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /opt/anaconda3/lib/python3.13/site-packages (from gymnasium[toy-text]) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /opt/anaconda3/lib/python3.13/site-packages (from gymnasium[toy-text]) (0.0.6)
# Requirement already satisfied: pygame-ce>=2.1.3 in /opt/anaconda3/lib/python3.13/site-packages (from gymnasium[toy-text]) (2.5.7)

# %%
import gymnasium as gym
import numpy as np
import random

# %%
# Sample env
env = gym.make("CliffWalking-v1")

# %%
# to check env created
print(env.observation_space.n) # states
print(env.action_space.n) # actions

starting_state, _ = env.reset() # 36 = 3 * 12 + 0
print(starting_state)
# Out:
# 48
# 4
# 36

# %% [markdown]
# ## SARSA Algo Implementation

# %%
gamma = 0.99
alpha = 0.5
epsilon = 0.1
episodes = 500

# %%
# Q-table => store Q-values

Q = np.zeros((48,4))

# %%
# Policy - epsilon-greedy policy

def epsilon_greedy(state):
    if random.random() < epsilon:
        return env.action_space.sample() # random action => EXPLORE
    else:
        return np.argmax(Q[state]) # EXPLOIT

# %%
for episode in range(episodes):

    render = (episode % 50 == 0)
    if render:
        env = gym.make("CliffWalking-v1",render_mode="human")
        print(f"rendering env for episodes= {episode+1}/500")
    else:
        env = gym.make("CliffWalking-v1")
        

    done = False  # when the episode has ended
    state, _ = env.reset()
    action = epsilon_greedy(state)

    total_reward = 0
    episode_len = 0

    while not done:
        next_state, reward, terminated, truncated, _ = env.step(action)
        done = terminated or truncated
        next_action = epsilon_greedy(next_state)

        # SARSA update
        Q[state, action] += alpha * (reward + gamma + (Q[next_state, next_action] - Q[state, action]))

        state = next_state
        action = next_action

        total_reward += reward
        episode_len +=1

    print(f"episode = {episode + 1}/500 : total reward ={total_reward} & episode len = {episode_len}")
    env.close()
# Out:
# rendering env for episodes= 1/500
# episode = 1/500 : total reward =-417 & episode len = 120
# episode = 2/500 : total reward =-1729 & episode len = 541
# episode = 3/500 : total reward =-233 & episode len = 134
# episode = 4/500 : total reward =-95 & episode len = 95
# episode = 5/500 : total reward =-54 & episode len = 54
# episode = 6/500 : total reward =-116 & episode len = 116
# episode = 7/500 : total reward =-152 & episode len = 53
# episode = 8/500 : total reward =-67 & episode len = 67
# episode = 9/500 : total reward =-73 & episode len = 73
# episode = 10/500 : total reward =-147 & episode len = 48
# episode = 11/500 : total reward =-177 & episode len = 78
# episode = 12/500 : total reward =-64 & episode len = 64
# episode = 13/500 : total reward =-137 & episode len = 38
# episode = 14/500 : total reward =-60 & episode len = 60
# episode = 15/500 : total reward =-27 & episode len = 27
# episode = 16/500 : total reward =-31 & episode len = 31
# episode = 17/500 : total reward =-38 & episode len = 38
# episode = 18/500 : total reward =-71 & episode len = 71
# episode = 19/500 : total reward =-80 & episode len = 80
# episode = 20/500 : total reward =-46 & episode len = 46
# episode = 21/500 : total reward =-36 & episode len = 36
# episode = 22/500 : total reward =-28 & episode len = 28
# episode = 23/500 : total reward =-28 & episode len = 28
# episode = 24/500 : total reward =-25 & episode len = 25
# episode = 25/500 : total reward =-67 & episode len = 67
# episode = 26/500 : total reward =-25 & episode len = 25
# episode = 27/500 : total reward =-21 & episode len = 21
# episode = 28/500 : total reward =-139 & episode len = 40
# episode = 29/500 : total reward =-38 & episode len = 38
# episode = 30/500 : total reward =-39 & episode len = 39
# episode = 31/500 : total reward =-47 & episode len = 47
# episode = 32/500 : total reward =-18 & episode len = 18
# episode = 33/500 : total reward =-31 & episode len = 31
# episode = 34/500 : total reward =-25 & episode len = 25
# episode = 35/500 : total reward =-25 & episode len = 25
# episode = 36/500 : total reward =-29 & episode len = 29
# episode = 37/500 : total reward =-35 & episode len = 35
# episode = 38/500 : total reward =-26 & episode len = 26
# episode = 39/500 : total reward =-30 & episode len = 30
# episode = 40/500 : total reward =-156 & episode len = 57
# episode = 41/500 : total reward =-31 & episode len = 31
# episode = 42/500 : total reward =-38 & episode len = 38
# episode = 43/500 : total reward =-32 & episode len = 32
# episode = 44/500 : total reward =-39 & episode len = 39
# episode = 45/500 : total reward =-148 & episode len = 49
# episode = 46/500 : total reward =-27 & episode len = 27
# episode = 47/500 : total reward =-29 & episode len = 29
# episode = 48/500 : total reward =-19 & episode len = 19
# episode = 49/500 : total reward =-38 & episode len = 38
# episode = 50/500 : total reward =-19 & episode len = 19
# rendering env for episodes= 51/500
# episode = 51/500 : total reward =-25 & episode len = 25
# episode = 52/500 : total reward =-17 & episode len = 17
# episode = 53/500 : total reward =-23 & episode len = 23
# episode = 54/500 : total reward =-351 & episode len = 351
# episode = 55/500 : total reward =-312 & episode len = 312
# episode = 56/500 : total reward =-25 & episode len = 25
# episode = 57/500 : total reward =-18 & episode len = 18
# episode = 58/500 : total reward =-20 & episode len = 20
# episode = 59/500 : total reward =-18 & episode len = 18
# episode = 60/500 : total reward =-19 & episode len = 19
# episode = 61/500 : total reward =-18 & episode len = 18
# episode = 62/500 : total reward =-17 & episode len = 17
# episode = 63/500 : total reward =-23 & episode len = 23
# episode = 64/500 : total reward =-21 & episode len = 21
# episode = 65/500 : total reward =-24 & episode len = 24
# episode = 66/500 : total reward =-34 & episode len = 34
# episode = 67/500 : total reward =-23 & episode len = 23
# episode = 68/500 : total reward =-348 & episode len = 249
# episode = 69/500 : total reward =-187 & episode len = 88
# episode = 70/500 : total reward =-614 & episode len = 515
# episode = 71/500 : total reward =-64 & episode len = 64
# episode = 72/500 : total reward =-30 & episode len = 30
# episode = 73/500 : total reward =-46 & episode len = 46
# episode = 74/500 : total reward =-337 & episode len = 337
# episode = 75/500 : total reward =-306 & episode len = 306
# episode = 76/500 : total reward =-31 & episode len = 31
# episode = 77/500 : total reward =-21 & episode len = 21
# episode = 78/500 : total reward =-20 & episode len = 20
# episode = 79/500 : total reward =-22 & episode len = 22
# episode = 80/500 : total reward =-19 & episode len = 19
# episode = 81/500 : total reward =-19 & episode len = 19
# episode = 82/500 : total reward =-445 & episode len = 247
# episode = 83/500 : total reward =-25 & episode len = 25
# episode = 84/500 : total reward =-27 & episode len = 27
# episode = 85/500 : total reward =-25 & episode len = 25
# episode = 86/500 : total reward =-21 & episode len = 21
# episode = 87/500 : total reward =-19 & episode len = 19
# episode = 88/500 : total reward =-19 & episode len = 19
# episode = 89/500 : total reward =-20 & episode len = 20
# episode = 90/500 : total reward =-66 & episode len = 66
# episode = 91/500 : total reward =-48 & episode len = 48
# episode = 92/500 : total reward =-3592 & episode len = 3097
# episode = 93/500 : total reward =-475 & episode len = 475
# episode = 94/500 : total reward =-24 & episode len = 24
# episode = 95/500 : total reward =-69 & episode len = 69
# episode = 96/500 : total reward =-4512 & episode len = 3819
# episode = 97/500 : total reward =-846 & episode len = 648
# episode = 98/500 : total reward =-131 & episode len = 32
# episode = 99/500 : total reward =-19 & episode len = 19
# episode = 100/500 : total reward =-20 & episode len = 20
# rendering env for episodes= 101/500
# episode = 101/500 : total reward =-23 & episode len = 23
# episode = 102/500 : total reward =-22 & episode len = 22
# episode = 103/500 : total reward =-21 & episode len = 21
# episode = 104/500 : total reward =-17 & episode len = 17
# episode = 105/500 : total reward =-18 & episode len = 18
# episode = 106/500 : total reward =-22 & episode len = 22
# episode = 107/500 : total reward =-22 & episode len = 22
# episode = 108/500 : total reward =-17 & episode len = 17
# episode = 109/500 : total reward =-19 & episode len = 19
# episode = 110/500 : total reward =-17 & episode len = 17
# episode = 111/500 : total reward =-19 & episode len = 19
# episode = 112/500 : total reward =-117 & episode len = 18
# episode = 113/500 : total reward =-20 & episode len = 20
# episode = 114/500 : total reward =-35 & episode len = 35
# episode = 115/500 : total reward =-45 & episode len = 45
# episode = 116/500 : total reward =-18 & episode len = 18
# episode = 117/500 : total reward =-93 & episode len = 93
# episode = 118/500 : total reward =-62 & episode len = 62
# episode = 119/500 : total reward =-178 & episode len = 79
# episode = 120/500 : total reward =-742 & episode len = 742
# episode = 121/500 : total reward =-17 & episode len = 17
# episode = 122/500 : total reward =-71 & episode len = 71
# episode = 123/500 : total reward =-44 & episode len = 44
# episode = 124/500 : total reward =-19 & episode len = 19
# episode = 125/500 : total reward =-17 & episode len = 17
# episode = 126/500 : total reward =-17 & episode len = 17
# episode = 127/500 : total reward =-17 & episode len = 17
# episode = 128/500 : total reward =-19 & episode len = 19
# episode = 129/500 : total reward =-17 & episode len = 17
# episode = 130/500 : total reward =-41 & episode len = 41
# episode = 131/500 : total reward =-17 & episode len = 17
# episode = 132/500 : total reward =-19 & episode len = 19
# episode = 133/500 : total reward =-17 & episode len = 17
# episode = 134/500 : total reward =-18 & episode len = 18
# episode = 135/500 : total reward =-98 & episode len = 98
# episode = 136/500 : total reward =-24 & episode len = 24
# episode = 137/500 : total reward =-81 & episode len = 81
# episode = 138/500 : total reward =-33 & episode len = 33
# episode = 139/500 : total reward =-17 & episode len = 17
# episode = 140/500 : total reward =-19 & episode len = 19
# episode = 141/500 : total reward =-25 & episode len = 25
# episode = 142/500 : total reward =-17 & episode len = 17
# episode = 143/500 : total reward =-17 & episode len = 17
# episode = 144/500 : total reward =-17 & episode len = 17
# episode = 145/500 : total reward =-24 & episode len = 24
# episode = 146/500 : total reward =-117 & episode len = 18
# episode = 147/500 : total reward =-20 & episode len = 20
# episode = 148/500 : total reward =-18 & episode len = 18
# episode = 149/500 : total reward =-17 & episode len = 17
# episode = 150/500 : total reward =-219 & episode len = 21
# rendering env for episodes= 151/500
# episode = 151/500 : total reward =-19 & episode len = 19
# episode = 152/500 : total reward =-17 & episode len = 17
# episode = 153/500 : total reward =-17 & episode len = 17
# episode = 154/500 : total reward =-20 & episode len = 20
# episode = 155/500 : total reward =-44 & episode len = 44
# episode = 156/500 : total reward =-19 & episode len = 19
# episode = 157/500 : total reward =-17 & episode len = 17
# episode = 158/500 : total reward =-18 & episode len = 18
# episode = 159/500 : total reward =-19 & episode len = 19
# episode = 160/500 : total reward =-21 & episode len = 21
# episode = 161/500 : total reward =-17 & episode len = 17
# episode = 162/500 : total reward =-19 & episode len = 19
# episode = 163/500 : total reward =-21 & episode len = 21
# episode = 164/500 : total reward =-21 & episode len = 21
# episode = 165/500 : total reward =-17 & episode len = 17
# episode = 166/500 : total reward =-19 & episode len = 19
# episode = 167/500 : total reward =-17 & episode len = 17
# episode = 168/500 : total reward =-17 & episode len = 17
# episode = 169/500 : total reward =-17 & episode len = 17
# episode = 170/500 : total reward =-21 & episode len = 21
# episode = 171/500 : total reward =-19 & episode len = 19
# episode = 172/500 : total reward =-17 & episode len = 17
# episode = 173/500 : total reward =-121 & episode len = 22
# episode = 174/500 : total reward =-18 & episode len = 18
# episode = 175/500 : total reward =-18 & episode len = 18
# episode = 176/500 : total reward =-31 & episode len = 31
# episode = 177/500 : total reward =-29 & episode len = 29
# episode = 178/500 : total reward =-19 & episode len = 19
# episode = 179/500 : total reward =-17 & episode len = 17
# episode = 180/500 : total reward =-17 & episode len = 17
# episode = 181/500 : total reward =-19 & episode len = 19
# episode = 182/500 : total reward =-18 & episode len = 18
# episode = 183/500 : total reward =-18 & episode len = 18
# episode = 184/500 : total reward =-24 & episode len = 24
# episode = 185/500 : total reward =-158 & episode len = 158
# episode = 186/500 : total reward =-19 & episode len = 19
# episode = 187/500 : total reward =-17 & episode len = 17
# episode = 188/500 : total reward =-19 & episode len = 19
# episode = 189/500 : total reward =-19 & episode len = 19
# episode = 190/500 : total reward =-17 & episode len = 17
# episode = 191/500 : total reward =-50 & episode len = 50
# episode = 192/500 : total reward =-25 & episode len = 25
# episode = 193/500 : total reward =-86 & episode len = 86
# episode = 194/500 : total reward =-17 & episode len = 17
# episode = 195/500 : total reward =-17 & episode len = 17
# episode = 196/500 : total reward =-17 & episode len = 17
# episode = 197/500 : total reward =-22 & episode len = 22
# episode = 198/500 : total reward =-28 & episode len = 28
# episode = 199/500 : total reward =-109 & episode len = 109
# episode = 200/500 : total reward =-22 & episode len = 22
# rendering env for episodes= 201/500
# episode = 201/500 : total reward =-21 & episode len = 21
# episode = 202/500 : total reward =-21 & episode len = 21
# episode = 203/500 : total reward =-20 & episode len = 20
# episode = 204/500 : total reward =-24 & episode len = 24
# episode = 205/500 : total reward =-23 & episode len = 23
# episode = 206/500 : total reward =-17 & episode len = 17
# episode = 207/500 : total reward =-20 & episode len = 20
# episode = 208/500 : total reward =-19 & episode len = 19
# episode = 209/500 : total reward =-17 & episode len = 17
# episode = 210/500 : total reward =-19 & episode len = 19
# episode = 211/500 : total reward =-628 & episode len = 430
# episode = 212/500 : total reward =-17 & episode len = 17
# episode = 213/500 : total reward =-260 & episode len = 260
# episode = 214/500 : total reward =-19 & episode len = 19
# episode = 215/500 : total reward =-27 & episode len = 27
# episode = 216/500 : total reward =-23 & episode len = 23
# episode = 217/500 : total reward =-38 & episode len = 38
# episode = 218/500 : total reward =-187 & episode len = 88
# episode = 219/500 : total reward =-41 & episode len = 41
# episode = 220/500 : total reward =-23 & episode len = 23
# episode = 221/500 : total reward =-68 & episode len = 68
# episode = 222/500 : total reward =-67 & episode len = 67
# episode = 223/500 : total reward =-25 & episode len = 25
# episode = 224/500 : total reward =-60 & episode len = 60
# episode = 225/500 : total reward =-17 & episode len = 17
# episode = 226/500 : total reward =-190 & episode len = 91
# episode = 227/500 : total reward =-19 & episode len = 19
# episode = 228/500 : total reward =-19 & episode len = 19
# episode = 229/500 : total reward =-94 & episode len = 94
# episode = 230/500 : total reward =-38 & episode len = 38
# episode = 231/500 : total reward =-22 & episode len = 22
# episode = 232/500 : total reward =-21 & episode len = 21
# episode = 233/500 : total reward =-22 & episode len = 22
# episode = 234/500 : total reward =-21 & episode len = 21
# episode = 235/500 : total reward =-37 & episode len = 37
# episode = 236/500 : total reward =-22 & episode len = 22
# episode = 237/500 : total reward =-23 & episode len = 23
# episode = 238/500 : total reward =-21 & episode len = 21
# episode = 239/500 : total reward =-68 & episode len = 68
# episode = 240/500 : total reward =-35 & episode len = 35
# episode = 241/500 : total reward =-19 & episode len = 19
# episode = 242/500 : total reward =-38 & episode len = 38
# episode = 243/500 : total reward =-19 & episode len = 19
# episode = 244/500 : total reward =-21 & episode len = 21
# episode = 245/500 : total reward =-45 & episode len = 45
# episode = 246/500 : total reward =-21 & episode len = 21
# episode = 247/500 : total reward =-21 & episode len = 21
# episode = 248/500 : total reward =-26 & episode len = 26
# episode = 249/500 : total reward =-111 & episode len = 111
# episode = 250/500 : total reward =-200 & episode len = 200
# rendering env for episodes= 251/500
# episode = 251/500 : total reward =-112 & episode len = 112
# episode = 252/500 : total reward =-20 & episode len = 20
# episode = 253/500 : total reward =-17 & episode len = 17
# episode = 254/500 : total reward =-21 & episode len = 21
# episode = 255/500 : total reward =-17 & episode len = 17
# episode = 256/500 : total reward =-19 & episode len = 19
# episode = 257/500 : total reward =-19 & episode len = 19
# episode = 258/500 : total reward =-20 & episode len = 20
# episode = 259/500 : total reward =-17 & episode len = 17
# episode = 260/500 : total reward =-17 & episode len = 17
# episode = 261/500 : total reward =-22 & episode len = 22
# episode = 262/500 : total reward =-117 & episode len = 18
# episode = 263/500 : total reward =-17 & episode len = 17
# episode = 264/500 : total reward =-21 & episode len = 21
# episode = 265/500 : total reward =-17 & episode len = 17
# episode = 266/500 : total reward =-21 & episode len = 21
# episode = 267/500 : total reward =-18 & episode len = 18
# episode = 268/500 : total reward =-19 & episode len = 19
# episode = 269/500 : total reward =-19 & episode len = 19
# episode = 270/500 : total reward =-17 & episode len = 17
# episode = 271/500 : total reward =-20 & episode len = 20
# episode = 272/500 : total reward =-21 & episode len = 21
# episode = 273/500 : total reward =-19 & episode len = 19
# episode = 274/500 : total reward =-92 & episode len = 92
# episode = 275/500 : total reward =-19 & episode len = 19
# episode = 276/500 : total reward =-20 & episode len = 20
# episode = 277/500 : total reward =-18 & episode len = 18
# episode = 278/500 : total reward =-19 & episode len = 19
# episode = 279/500 : total reward =-42 & episode len = 42
# episode = 280/500 : total reward =-23 & episode len = 23
# episode = 281/500 : total reward =-44 & episode len = 44
# episode = 282/500 : total reward =-19 & episode len = 19
# episode = 283/500 : total reward =-31 & episode len = 31
# episode = 284/500 : total reward =-18 & episode len = 18
# episode = 285/500 : total reward =-25 & episode len = 25
# episode = 286/500 : total reward =-19 & episode len = 19
# episode = 287/500 : total reward =-55 & episode len = 55
# episode = 288/500 : total reward =-17 & episode len = 17
# episode = 289/500 : total reward =-20 & episode len = 20
# episode = 290/500 : total reward =-30 & episode len = 30
# episode = 291/500 : total reward =-112 & episode len = 112
# episode = 292/500 : total reward =-79 & episode len = 79
# episode = 293/500 : total reward =-51 & episode len = 51
# episode = 294/500 : total reward =-57 & episode len = 57
# episode = 295/500 : total reward =-61 & episode len = 61
# episode = 296/500 : total reward =-38 & episode len = 38
# episode = 297/500 : total reward =-27 & episode len = 27
# episode = 298/500 : total reward =-17 & episode len = 17
# episode = 299/500 : total reward =-21 & episode len = 21
# episode = 300/500 : total reward =-22 & episode len = 22
# rendering env for episodes= 301/500
# episode = 301/500 : total reward =-17 & episode len = 17
# episode = 302/500 : total reward =-17 & episode len = 17
# episode = 303/500 : total reward =-21 & episode len = 21
# episode = 304/500 : total reward =-21 & episode len = 21
# episode = 305/500 : total reward =-21 & episode len = 21
# episode = 306/500 : total reward =-260 & episode len = 62
# episode = 307/500 : total reward =-22 & episode len = 22
# episode = 308/500 : total reward =-17 & episode len = 17
# episode = 309/500 : total reward =-44 & episode len = 44
# episode = 310/500 : total reward =-21 & episode len = 21
# episode = 311/500 : total reward =-17 & episode len = 17
# episode = 312/500 : total reward =-19 & episode len = 19
# episode = 313/500 : total reward =-29 & episode len = 29
# episode = 314/500 : total reward =-18 & episode len = 18
# episode = 315/500 : total reward =-24 & episode len = 24
# episode = 316/500 : total reward =-17 & episode len = 17
# episode = 317/500 : total reward =-18 & episode len = 18
# episode = 318/500 : total reward =-35 & episode len = 35
# episode = 319/500 : total reward =-51 & episode len = 51
# episode = 320/500 : total reward =-44 & episode len = 44
# episode = 321/500 : total reward =-131 & episode len = 131
# episode = 322/500 : total reward =-41 & episode len = 41
# episode = 323/500 : total reward =-20 & episode len = 20
# episode = 324/500 : total reward =-18 & episode len = 18
# episode = 325/500 : total reward =-83 & episode len = 83
# episode = 326/500 : total reward =-21 & episode len = 21
# episode = 327/500 : total reward =-17 & episode len = 17
# episode = 328/500 : total reward =-17 & episode len = 17
# episode = 329/500 : total reward =-21 & episode len = 21
# episode = 330/500 : total reward =-21 & episode len = 21
# episode = 331/500 : total reward =-18 & episode len = 18
# episode = 332/500 : total reward =-17 & episode len = 17
# episode = 333/500 : total reward =-19 & episode len = 19
# episode = 334/500 : total reward =-41 & episode len = 41
# episode = 335/500 : total reward =-18 & episode len = 18
# episode = 336/500 : total reward =-119 & episode len = 20
# episode = 337/500 : total reward =-21 & episode len = 21
# episode = 338/500 : total reward =-25 & episode len = 25
# episode = 339/500 : total reward =-18 & episode len = 18
# episode = 340/500 : total reward =-20 & episode len = 20
# episode = 341/500 : total reward =-17 & episode len = 17
# episode = 342/500 : total reward =-19 & episode len = 19
# episode = 343/500 : total reward =-134 & episode len = 35
# episode = 344/500 : total reward =-21 & episode len = 21
# episode = 345/500 : total reward =-225 & episode len = 126
# episode = 346/500 : total reward =-55 & episode len = 55
# episode = 347/500 : total reward =-41 & episode len = 41
# episode = 348/500 : total reward =-17 & episode len = 17
# episode = 349/500 : total reward =-17 & episode len = 17
# episode = 350/500 : total reward =-21 & episode len = 21
# rendering env for episodes= 351/500
# episode = 351/500 : total reward =-17 & episode len = 17
# episode = 352/500 : total reward =-86 & episode len = 86
# episode = 353/500 : total reward =-155 & episode len = 56
# episode = 354/500 : total reward =-118 & episode len = 118
# episode = 355/500 : total reward =-72 & episode len = 72
# episode = 356/500 : total reward =-68 & episode len = 68
# episode = 357/500 : total reward =-30 & episode len = 30
# episode = 358/500 : total reward =-25 & episode len = 25
# episode = 359/500 : total reward =-181 & episode len = 82
# episode = 360/500 : total reward =-4947 & episode len = 4848
# episode = 361/500 : total reward =-312 & episode len = 312
# episode = 362/500 : total reward =-251 & episode len = 251
# episode = 363/500 : total reward =-43 & episode len = 43
# episode = 364/500 : total reward =-18 & episode len = 18
# episode = 365/500 : total reward =-17 & episode len = 17
# episode = 366/500 : total reward =-17 & episode len = 17
# episode = 367/500 : total reward =-18 & episode len = 18
# episode = 368/500 : total reward =-19 & episode len = 19
# episode = 369/500 : total reward =-67 & episode len = 67
# episode = 370/500 : total reward =-1526 & episode len = 1427
# episode = 371/500 : total reward =-27 & episode len = 27
# episode = 372/500 : total reward =-27 & episode len = 27
# episode = 373/500 : total reward =-21 & episode len = 21
# episode = 374/500 : total reward =-26 & episode len = 26
# episode = 375/500 : total reward =-18 & episode len = 18
# episode = 376/500 : total reward =-19 & episode len = 19
# episode = 377/500 : total reward =-18 & episode len = 18
# episode = 378/500 : total reward =-17 & episode len = 17
# episode = 379/500 : total reward =-21 & episode len = 21
# episode = 380/500 : total reward =-18 & episode len = 18
# episode = 381/500 : total reward =-511 & episode len = 412
# episode = 382/500 : total reward =-105 & episode len = 105
# episode = 383/500 : total reward =-105 & episode len = 105
# episode = 384/500 : total reward =-65 & episode len = 65
# episode = 385/500 : total reward =-122 & episode len = 122
# episode = 386/500 : total reward =-37 & episode len = 37
# episode = 387/500 : total reward =-20 & episode len = 20
# episode = 388/500 : total reward =-25 & episode len = 25
# episode = 389/500 : total reward =-19 & episode len = 19
# episode = 390/500 : total reward =-19 & episode len = 19
# episode = 391/500 : total reward =-50 & episode len = 50
# episode = 392/500 : total reward =-27 & episode len = 27
# episode = 393/500 : total reward =-41 & episode len = 41
# episode = 394/500 : total reward =-24 & episode len = 24
# episode = 395/500 : total reward =-21 & episode len = 21
# episode = 396/500 : total reward =-19 & episode len = 19
# episode = 397/500 : total reward =-21 & episode len = 21
# episode = 398/500 : total reward =-23 & episode len = 23
# episode = 399/500 : total reward =-21 & episode len = 21
# episode = 400/500 : total reward =-55 & episode len = 55
# rendering env for episodes= 401/500
# episode = 401/500 : total reward =-21 & episode len = 21
# episode = 402/500 : total reward =-17 & episode len = 17
# episode = 403/500 : total reward =-19 & episode len = 19
# episode = 404/500 : total reward =-21 & episode len = 21
# episode = 405/500 : total reward =-19 & episode len = 19
# episode = 406/500 : total reward =-24 & episode len = 24
# episode = 407/500 : total reward =-20 & episode len = 20
# episode = 408/500 : total reward =-20 & episode len = 20
# episode = 409/500 : total reward =-404 & episode len = 305
# episode = 410/500 : total reward =-23 & episode len = 23
# episode = 411/500 : total reward =-17 & episode len = 17
# episode = 412/500 : total reward =-20 & episode len = 20
# episode = 413/500 : total reward =-31 & episode len = 31
# episode = 414/500 : total reward =-17 & episode len = 17
# episode = 415/500 : total reward =-86 & episode len = 86
# episode = 416/500 : total reward =-474 & episode len = 474
# episode = 417/500 : total reward =-49 & episode len = 49
# episode = 418/500 : total reward =-27 & episode len = 27
# episode = 419/500 : total reward =-24 & episode len = 24
# episode = 420/500 : total reward =-18 & episode len = 18
# episode = 421/500 : total reward =-21 & episode len = 21
# episode = 422/500 : total reward =-25 & episode len = 25
# episode = 423/500 : total reward =-384 & episode len = 384
# episode = 424/500 : total reward =-679 & episode len = 580
# episode = 425/500 : total reward =-122 & episode len = 122
# episode = 426/500 : total reward =-38 & episode len = 38
# episode = 427/500 : total reward =-29 & episode len = 29
# episode = 428/500 : total reward =-63 & episode len = 63
# episode = 429/500 : total reward =-143 & episode len = 44
# episode = 430/500 : total reward =-58 & episode len = 58
# episode = 431/500 : total reward =-123 & episode len = 24
# episode = 432/500 : total reward =-21 & episode len = 21
# episode = 433/500 : total reward =-55 & episode len = 55
# episode = 434/500 : total reward =-22 & episode len = 22
# episode = 435/500 : total reward =-265 & episode len = 166
# episode = 436/500 : total reward =-25 & episode len = 25
# episode = 437/500 : total reward =-122 & episode len = 23
# episode = 438/500 : total reward =-33 & episode len = 33
# episode = 439/500 : total reward =-60 & episode len = 60
# episode = 440/500 : total reward =-86 & episode len = 86
# episode = 441/500 : total reward =-95 & episode len = 95
# episode = 442/500 : total reward =-18 & episode len = 18
# episode = 443/500 : total reward =-20 & episode len = 20
# episode = 444/500 : total reward =-21 & episode len = 21
# episode = 445/500 : total reward =-20 & episode len = 20
# episode = 446/500 : total reward =-136 & episode len = 37
# episode = 447/500 : total reward =-18 & episode len = 18
# episode = 448/500 : total reward =-20 & episode len = 20
# episode = 449/500 : total reward =-18 & episode len = 18
# episode = 450/500 : total reward =-17 & episode len = 17
# rendering env for episodes= 451/500
# episode = 451/500 : total reward =-18 & episode len = 18
# episode = 452/500 : total reward =-19 & episode len = 19
# episode = 453/500 : total reward =-17 & episode len = 17
# episode = 454/500 : total reward =-19 & episode len = 19
# episode = 455/500 : total reward =-17 & episode len = 17
# episode = 456/500 : total reward =-21 & episode len = 21
# episode = 457/500 : total reward =-18 & episode len = 18
# episode = 458/500 : total reward =-21 & episode len = 21
# episode = 459/500 : total reward =-21 & episode len = 21
# episode = 460/500 : total reward =-17 & episode len = 17
# episode = 461/500 : total reward =-38 & episode len = 38
# episode = 462/500 : total reward =-18 & episode len = 18
# episode = 463/500 : total reward =-17 & episode len = 17
# episode = 464/500 : total reward =-17 & episode len = 17
# episode = 465/500 : total reward =-19 & episode len = 19
# episode = 466/500 : total reward =-19 & episode len = 19
# episode = 467/500 : total reward =-22 & episode len = 22
# episode = 468/500 : total reward =-17 & episode len = 17
# episode = 469/500 : total reward =-17 & episode len = 17
# episode = 470/500 : total reward =-17 & episode len = 17
# episode = 471/500 : total reward =-17 & episode len = 17
# episode = 472/500 : total reward =-283 & episode len = 283
# episode = 473/500 : total reward =-19 & episode len = 19
# episode = 474/500 : total reward =-26 & episode len = 26
# episode = 475/500 : total reward =-22 & episode len = 22
# episode = 476/500 : total reward =-17 & episode len = 17
# episode = 477/500 : total reward =-86 & episode len = 86
# episode = 478/500 : total reward =-18 & episode len = 18
# episode = 479/500 : total reward =-17 & episode len = 17
# episode = 480/500 : total reward =-19 & episode len = 19
# episode = 481/500 : total reward =-19 & episode len = 19
# episode = 482/500 : total reward =-17 & episode len = 17
# episode = 483/500 : total reward =-19 & episode len = 19
# episode = 484/500 : total reward =-19 & episode len = 19
# episode = 485/500 : total reward =-17 & episode len = 17
# episode = 486/500 : total reward =-17 & episode len = 17
# episode = 487/500 : total reward =-20 & episode len = 20
# episode = 488/500 : total reward =-21 & episode len = 21
# episode = 489/500 : total reward =-54 & episode len = 54
# episode = 490/500 : total reward =-235 & episode len = 136
# episode = 491/500 : total reward =-21 & episode len = 21
# episode = 492/500 : total reward =-19 & episode len = 19
# episode = 493/500 : total reward =-17 & episode len = 17
# episode = 494/500 : total reward =-21 & episode len = 21
# episode = 495/500 : total reward =-18 & episode len = 18
# episode = 496/500 : total reward =-18 & episode len = 18
# episode = 497/500 : total reward =-18 & episode len = 18
# episode = 498/500 : total reward =-17 & episode len = 17
# episode = 499/500 : total reward =-34 & episode len = 34
# episode = 500/500 : total reward =-34 & episode len = 34

# %%
# What did our agent learn?

env = gym.make("CliffWalking-v1",render_mode = "human")
state, _ = env.reset()
done = False
total_reward = 0
episode_len =0

while not done:
    action = np.argmax(Q[state])
    state, reward, terminated, truncated, _ = env.step(action)
    done = terminated or truncated


    #state =  next_state
    total_reward += reward
    episode_len += 1

print(f"total reward = {total_reward} & episode len : {episode_len}")
env.close()
# Out:
# total reward = -17 & episode len : 17
